# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from scipy.ndimage.interpolation import shift
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train_fwYjLYX.csv')
df.head()
# Out:
#   application_date  segment  branch_id        state  zone  case_count
# 0       2017-04-01        1        1.0  WEST BENGAL  EAST        40.0
# 1       2017-04-03        1        1.0  WEST BENGAL  EAST         5.0
# 2       2017-04-04        1        1.0  WEST BENGAL  EAST         4.0
# 3       2017-04-05        1        1.0  WEST BENGAL  EAST       113.0
# 4       2017-04-07        1        1.0  WEST BENGAL  EAST        76.0

# %%
df.columns
# Out:
# Index(['application_date', 'segment', 'branch_id', 'state', 'zone',
#        'case_count', 'new'],
#       dtype='object')

# %%
df.head()
# Out:
#   application_date  segment  branch_id        state  zone  case_count  new
# 0       2017-04-01        1        1.0  WEST BENGAL  EAST        40.0   15
# 1       2017-04-03        1        1.0  WEST BENGAL  EAST         5.0   15
# 2       2017-04-04        1        1.0  WEST BENGAL  EAST         4.0   15
# 3       2017-04-05        1        1.0  WEST BENGAL  EAST       113.0   15
# 4       2017-04-07        1        1.0  WEST BENGAL  EAST        76.0   15

# %%
df.pop('new')
# Out:
# 0        15
# 1        15
# 2        15
# 3        15
# 4        15
#          ..
# 80397    15
# 80398    15
# 80399    15
# 80400    15
# 80401    15
# Name: new, Length: 80402, dtype: int64

# %%
df.head()
# Out:
#   application_date  segment  branch_id        state  zone  case_count
# 0       2017-04-01        1        1.0  WEST BENGAL  EAST        40.0
# 1       2017-04-03        1        1.0  WEST BENGAL  EAST         5.0
# 2       2017-04-04        1        1.0  WEST BENGAL  EAST         4.0
# 3       2017-04-05        1        1.0  WEST BENGAL  EAST       113.0
# 4       2017-04-07        1        1.0  WEST BENGAL  EAST        76.0

# %%
k=list(df['state'].unique())
print(k)
# Out:
# ['WEST BENGAL', 'DELHI', 'KARNATAKA', 'TAMIL NADU', 'UTTAR PRADESH', 'PUNJAB', 'TELANGANA', 'ANDHRA PRADESH', 'MAHARASHTRA', 'ORISSA', 'GUJARAT', 'ASSAM', 'JHARKHAND', 'UTTARAKHAND', 'KERALA', 'CHHATTISGARH', 'BIHAR', 'TRIPURA', 'MADHYA PRADESH', 'HARYANA']

# %%
p=['segment','branch_id']
for a in p:
    df.pop(a)
df.head()
# Out:
#   application_date        state  zone  case_count
# 0       2017-04-01  WEST BENGAL  EAST        40.0
# 1       2017-04-03  WEST BENGAL  EAST         5.0
# 2       2017-04-04  WEST BENGAL  EAST         4.0
# 3       2017-04-05  WEST BENGAL  EAST       113.0
# 4       2017-04-07  WEST BENGAL  EAST        76.0

# %%
for a in k:
    x=df.loc[df['state'] == a]
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 10.5)
    plt.plot(x['case_count'].values, label =a)
    plt.legend()
    plt.show()

# %%
x=df.loc[df['state'] == 'WEST BENGAL']
x.describe()
